# %%
import pandas as pd

# %%
import os
os.chdir('data')

# %%
from datetime import datetime, timedelta, date, time

# %% [markdown]
# # Загрузка данных

# %%
def get_period(start_date, finish_date, period='m'):
    period_values = []
    i = 0
    curr_date = start_date
    if period == 'm':
        period_values.append(curr_date)
        while curr_date < finish_date:
            y = (start_date.month + i) // 12
            m = (start_date.month + i) % 12 + 1
            curr_date = date(start_date.year + y, m, 1)
            period_values.append(curr_date)
            i = i + 1
    elif period == 'w':
        while curr_date <= finish_date:
            period_values.append(curr_date)
            curr_date = curr_date + timedelta(days=7)
    return period_values

# %%
def load_from_csv(filename, start_date, finish_date, period='m',
                  selected_locs=None, selected_cols=['LOCATION', 'TIME', 'Value'], sep=','):
    df = pd.read_csv(f"{filename}.csv", sep=sep, parse_dates=[selected_cols[1]])
    df = df[selected_cols]
    df.rename(columns={selected_cols[2]: filename, selected_cols[1]: "period"}, inplace=True)
    df.set_index('period', inplace=True)
    
    period_df = pd.DataFrame(data={'period': get_period(start_date, finish_date, period=period)})
    period_df.set_index('period', inplace=True)
    if not selected_locs:
        selected_locs = list(df[selected_cols[0]].unique())
    for col in selected_locs:
        loc_df = df[(df[selected_cols[0]] == col)][[filename]]
        loc_df.rename(columns={filename: f"{filename}_{col}"}, inplace=True)
        period_df = period_df.join(loc_df, how='left')
    return period_df

# %%
def fill_nan_last_val(df, sym=None):
    new_df = df.copy()
    for col in df.columns:
        if not sym:
            f_isna = (new_df[col].isna())
            f_notna = (df[col].notna())
        else:
            f_isna = (new_df[col] == '..')
            f_notna = (new_df[col] != '..')
        for index, value in new_df.loc[f_isna][col].items():
            s = df[((df[col].notna()) & (df.index <= index))][col]
            if len(s):
                last_val = s.iloc[-1]
            else:
                last_val = df[(f_notna & (df.index > index))][col].iloc[0]
            df.loc[index, col] = last_val
            df[col] = df[col].astype('float64', copy=False)
    #return df

# %%
def get_df_from_excel(filename, start_date, finish_date,
                      skiprows, skipfooter, cols_rename, period='m', parse_dates=['Date'],
                      select_cols=None):
    df = pd.read_excel(f"{filename}.xlsx", decimal=',', 
                       parse_dates=parse_dates, skiprows=skiprows, skipfooter=skipfooter)
    if select_cols:
        df = df[select_cols]
    df.rename(columns=cols_rename, inplace=True)
    df.set_index('period', inplace=True)
    
    period_df = pd.DataFrame(data={'period': get_period(start_date, finish_date, period=period)})
    period_df.set_index('period', inplace=True)
    return period_df.join(df, how='left')

# %% [markdown]
# # Параметры

# %%
start_date = date(2000, 1, 1)
finish_date = date(2022, 6, 1)

# %% [markdown]
# ### Обработка BCI

# %%
bci_df = load_from_csv('BCI', start_date, finish_date)

# %%
fill_nan_last_val(bci_df)

# %% [markdown]
# ### CCI

# %%
cci_df = load_from_csv('CCI', start_date, finish_date)
fill_nan_last_val(cci_df)

# %%
cci_df.tail()
# Out:
#              CCI_JPN   CCI_AUS  CCI_OECD   CCI_GBR   CCI_ZAF   CCI_USA  \
# period
# 2022-02-01  98.00504  99.86245  98.28129  97.40088  98.28765  97.08185
# 2022-03-01  97.58710  99.59343  97.72383  95.79521  98.06467  96.92998
# 2022-04-01  97.28867  99.35078  97.28673  94.11323  98.06467  97.05984
# 2022-05-01  97.28867  99.35078  97.28673  94.11323  98.06467  97.05984
# 2022-06-01  97.28867  99.35078  97.28673  94.11323  98.06467  97.05984
#
#              CCI_BRA   CCI_CHN   CCI_G-7   CCI_IDN  CCI_EA19   CCI_RUS
# period
# 2022-02-01  98.24409  102.7179  97.93880  100.9402  99.11861  97.62921
# 2022-03-01  98.33363  101.4161  97.39916  100.6590  97.51540  97.62921
# 2022-04-01  98.54461  101.4161  97.06406  100.6590  96.11227  97.62921
# 2022-05-01  98.54461  101.4161  97.06406  100.6590  96.11227  97.62921
# 2022-06-01  98.54461  101.4161  97.06406  100.6590  96.11227  97.62921

# %% [markdown]
# ### CLI

# %%
cli_df = load_from_csv('CLI', start_date, finish_date)
fill_nan_last_val(cli_df)

# %%
cli_df.tail()
# Out:
#              CLI_GBR   CLI_CHN   CLI_BRA  CLI_OECD   CLI_IDN   CLI_JPN  \
# period
# 2022-02-01  100.6501  99.40155  98.78979  100.3172  96.53909  100.5638
# 2022-03-01  100.3470  99.38866  98.47284  100.2351  96.43018  100.5751
# 2022-04-01  100.0326  99.38767  98.25556  100.1643  96.36440  100.5995
# 2022-05-01  100.0326  99.38767  98.25556  100.1643  96.36440  100.5995
# 2022-06-01  100.0326  99.38767  98.25556  100.1643  96.36440  100.5995
#
#              CLI_USA    CLI_IND   CLI_AUS   CLI_CAN   CLI_ZAF   CLI_G-7  \
# period
# 2022-02-01  100.0371  100.09300  98.95084  100.1341  101.0914  100.2271
# 2022-03-01  100.0779  100.01170  98.75658  100.0726  101.0999  100.1705
# 2022-04-01  100.1464   99.93071  98.59047  100.0274  101.0918  100.1361
# 2022-05-01  100.1464   99.93071  98.59047  100.0274  101.0918  100.1361
# 2022-06-01  100.1464   99.93071  98.59047  100.0274  101.0918  100.1361
#
#              CLI_RUS  CLI_EA19
# period
# 2022-02-01  103.0155  100.4592
# 2022-03-01  103.0155  100.2647
# 2022-04-01  103.0155  100.0879
# 2022-05-01  103.0155  100.0879
# 2022-06-01  103.0155  100.0879

# %% [markdown]
# ### PPI Manufacturing domestic market

# %%
ppi_dm_df = load_from_csv('PPI Manufacturing domestic market', 
                          start_date, finish_date, selected_locs=['OECD'])
fill_nan_last_val(ppi_dm_df)

# %%
ppi_dm_df.tail()
# Out:
#             PPI Manufacturing domestic market_OECD
# period
# 2022-02-01                                132.1458
# 2022-03-01                                136.4849
# 2022-04-01                                139.3227
# 2022-05-01                                139.3227
# 2022-06-01                                139.3227

# %% [markdown]
# ### PPI Manufacturing total market

# %%
ppi_tm_df = load_from_csv('PPI Manufacturing total market', 
                          start_date, finish_date, selected_locs=['USA'])
fill_nan_last_val(ppi_tm_df)

# %%
ppi_tm_df.tail()
# Out:
#             PPI Manufacturing total market_USA
# period
# 2022-02-01                             127.855
# 2022-03-01                             132.132
# 2022-04-01                             134.284
# 2022-05-01                             134.284
# 2022-06-01                             134.284

# %% [markdown]
# ### Leading Indicators OECD  Component series  Interest rate spread  Original series

# %%
li_irs_df = load_from_csv('Leading Indicators OECD  Component series  Interest rate spread  Original series',
                           start_date, finish_date,
                           selected_locs=['USA'],
                           selected_cols=['LOCATION', 'TIME', 'Value'],
                           sep='\t')
fill_nan_last_val(li_irs_df)

# %%
li_irs_df.tail()
# Out:
#             Leading Indicators OECD  Component series  Interest rate spread  Original series_USA
# period
# 2022-02-01                                               1.85
# 2022-03-01                                               1.93
# 2022-04-01                                               2.42
# 2022-05-01                                               2.42
# 2022-06-01                                               2.42

# %% [markdown]
# ### Leading Indicators OECD > Component series > Share prices > Normalised-Level

# %%
li_sp_df = load_from_csv('Leading Indicators OECD  Component series  Share prices  Normalised-Level',
                         start_date, finish_date,
                         selected_locs=['USA'],
                         selected_cols=['LOCATION', 'TIME', 'Value'],
                         sep='\t')
fill_nan_last_val(li_sp_df)

# %%
li_sp_df.tail()
# Out:
#             Leading Indicators OECD  Component series  Share prices  Normalised-Level_USA
# period
# 2022-02-01                                         100.344766
# 2022-03-01                                         100.167408
# 2022-04-01                                         100.003445
# 2022-05-01                                         100.003445
# 2022-06-01                                         100.003445

# %% [markdown]
# ### Industrial Production

# %%
ip_files = ['Industrial Production  Brazil', 'Industrial Production  Russia', 
            'Industrial Production E. Europe', 'Industrial Production South East Asia Average']

# %%
ip_dfs = list(map(lambda filename: 
                  get_df_from_excel(filename, start_date, finish_date,
                  skiprows=5, skipfooter=7, 
                  cols_rename={"% Yr/Yr": filename, "Date": "period"}), ip_files))
ip_df = pd.concat(ip_dfs, axis=1, join='inner')
fill_nan_last_val(ip_df)

# %%
ip_df.tail()
# Out:
#             Industrial Production  Brazil  Industrial Production  Russia  \
# period
# 2022-02-01                           -4.3                            6.3
# 2022-03-01                           -2.1                            3.1
# 2022-04-01                           -2.1                            3.1
# 2022-05-01                           -2.1                            3.1
# 2022-06-01                           -2.1                            3.1
#
#             Industrial Production E. Europe  \
# period
# 2022-02-01                          6.53662
# 2022-03-01                          6.53662
# 2022-04-01                          6.53662
# 2022-05-01                          6.53662
# 2022-06-01                          6.53662
#
#             Industrial Production South East Asia Average
# period
# 2022-02-01                                        5.77101
# 2022-03-01                                        5.77101
# 2022-04-01                                        5.77101
# 2022-05-01                                        5.77101
# 2022-06-01                                        5.77101

# %% [markdown]
# ### US

# %%
us_files = ['US Total Coking Coal Exports', 
            'US Seaborne Coking Coal Exports']

# %%
df_us_coking_coal_exp = \
get_df_from_excel(us_files[0], start_date, finish_date,
                  skiprows=5, skipfooter=6, 
                  cols_rename={",000 tonnes": us_files[0], "Date": "period"})

# %%
df_us_seaborne_coal_exp = \
get_df_from_excel(us_files[1], start_date, finish_date,
                  skiprows=5, skipfooter=7, 
                  cols_rename={",000 tonnes": us_files[1], "Date": "period"})

# %%
us_df = pd.concat([df_us_coking_coal_exp, df_us_seaborne_coal_exp], axis=1, join='inner')
fill_nan_last_val(us_df)

# %%
us_df.tail()
# Out:
#             US Total Coking Coal Exports  US Seaborne Coking Coal Exports
# period
# 2022-02-01                        3627.0                           3626.0
# 2022-03-01                        3627.0                           3626.0
# 2022-04-01                        3627.0                           3626.0
# 2022-05-01                        3627.0                           3626.0
# 2022-06-01                        3627.0                           3626.0

# %% [markdown]
# ### Exports Imports in goods OECD

# %%
def replace_non_val(df, cols, sym='..'):
    for col in cols:
        df.loc[(df[col] == '..'), col] = 0
        df[col] = df[col].astype('float64', copy=False)
    return df

# %%
filename = 'Exports Imports in goods OECD'

selected_cols = ['Subject', 'LOCATION', 'TIME', 'Value']
exp_imp_in_goods_df = pd.read_csv(f"{filename}.csv", sep='\t', parse_dates=['TIME'])
exp_imp_in_goods_df = exp_imp_in_goods_df[selected_cols]
exp_imp_in_goods_df.rename(columns={'TIME': "period"}, inplace=True)
exp_imp_in_goods_df = exp_imp_in_goods_df.set_index('period')

# %%
period_df = pd.DataFrame(data={'period': get_period(start_date, finish_date)})
period_df.set_index('period', inplace=True)
exp_in_goods_df = exp_imp_in_goods_df[(exp_imp_in_goods_df.Subject == 'Exports in goods (value)')]
exp_in_goods_df = exp_in_goods_df[['LOCATION', 'Value']]
locs = exp_in_goods_df['LOCATION'].unique()

exp_in_goods_locs = []
for loc in locs:
    loc_df = exp_in_goods_df[(exp_in_goods_df['LOCATION'] == loc)][['Value']]
    loc_df.rename(columns={'Value': f"Exports in goods (value)-US-Dollar_{loc}"}, inplace=True)
    loc_df = period_df.join(loc_df, how='left')
    exp_in_goods_locs.append(loc_df)
exp_in_goods_df = pd.concat(exp_in_goods_locs, axis=1, join='inner')

fill_nan_last_val(exp_in_goods_df, sym='..')
fill_nan_last_val(exp_in_goods_df)
exp_in_goods_df['Exports in goods (value)-US-Dollar_OECD_Average'] = \
exp_in_goods_df[exp_in_goods_df.columns[:-1]].mean(axis=1)

# %%
exp_in_goods_df.tail()
# Out:
#             Exports in goods (value)-US-Dollar_AUS  \
# period
# 2022-02-01                                29.41692
# 2022-03-01                                32.82041
# 2022-04-01                                33.33560
# 2022-05-01                                33.33560
# 2022-06-01                                33.33560
#
#             Exports in goods (value)-US-Dollar_CAN  \
# period
# 2022-02-01                                42.13962
# 2022-03-01                                54.05064
# 2022-04-01                                54.05064
# 2022-05-01                                54.05064
# 2022-06-01                                54.05064
#
#             Exports in goods (value)-US-Dollar_FRA  \
# period
# 2022-02-01                                50.62971
# 2022-03-01                                56.11316
# 2022-04-01                                56.11316
# 2022-05-01                                56.11316
# 2022-06-01                                56.11316
#
#             Exports in goods (value)-US-Dollar_DEU  \
# period
# 2022-02-01                                139.6229
# 2022-03-01                                151.8868
# 2022-04-01                                151.8868
# 2022-05-01                                151.8868
# 2022-06-01                                151.8868
#
#             Exports in goods (value)-US-Dollar_ITA  \
# period
# 2022-02-01                                53.60439
# 2022-03-01                                62.10876
# 2022-04-01                                62.10876
# 2022-05-01                                62.10876
# 2022-06-01                                62.10876
#
#             Exports in goods (value)-US-Dollar_JPN  \
# period
# 2022-02-01                                62.43734
# 2022-03-01                                71.36413
# 2022-04-01                                63.92207
# 2022-05-01                                63.92207
# 2022-06-01                                63.92207
#
#             Exports in goods (value)-US-Dollar_KOR  \
# period
# 2022-02-01                                53.99846
# 2022-03-01                                63.79319
# 2022-04-01                                57.83341
# 2022-05-01                                57.83341
# 2022-06-01                                57.83341
#
#             Exports in goods (value)-US-Dollar_MEX  \
# period
# 2022-02-01                                46.23926
# 2022-03-01                                51.90614
# 2022-04-01                                47.47947
# 2022-05-01                                47.47947
# 2022-06-01                                47.47947
#
#             Exports in goods (value)-US-Dollar_CHE  \
# period
# 2022-02-01                                25.83490
# 2022-03-01                                26.99028
# 2022-04-01                                22.73160
# 2022-05-01                                22.73160
# 2022-06-01                                22.73160
#
#             Exports in goods (value)-US-Dollar_TUR  ...  \
# period                                              ...
# 2022-02-01                                19.91107  ...
# 2022-03-01                                22.68892  ...
# 2022-04-01                                23.36755  ...
# 2022-05-01                                23.36755  ...
# 2022-06-01                                23.36755  ...
#
#             Exports in goods (value)-US-Dollar_POL  \
# period
# 2022-02-01                                28.97130
# 2022-03-01                                30.24796
# 2022-04-01                                30.24796
# 2022-05-01                                30.24796
# 2022-06-01                                30.24796
#
#             Exports in goods (value)-US-Dollar_PRT  \
# period
# 2022-02-01                                6.769989
# 2022-03-01                                7.278731
# 2022-04-01                                7.278731
# 2022-05-01                                7.278731
# 2022-06-01                                7.278731
#
#             Exports in goods (value)-US-Dollar_SVK  \
# period
# 2022-02-01                                9.150682
# 2022-03-01                                9.503868
# 2022-04-01                                9.503868
# 2022-05-01                                9.503868
# 2022-06-01                                9.503868
#
#             Exports in goods (value)-US-Dollar_SWE  \
# period
# 2022-02-01                                16.29527
# 2022-03-01                                19.10878
# 2022-04-01                                16.32535
# 2022-05-01                                16.32535
# 2022-06-01                                16.32535
#
#             Exports in goods (value)-US-Dollar_EST  \
# period
# 2022-02-01                                1.691987
# 2022-03-01                                2.181051
# 2022-04-01                                2.181051
# 2022-05-01                                2.181051
# 2022-06-01                                2.181051
#
#             Exports in goods (value)-US-Dollar_LVA  \
# period
# 2022-02-01                                1.752678
# 2022-03-01                                2.067640
# 2022-04-01                                2.067640
# 2022-05-01                                2.067640
# 2022-06-01                                2.067640
#
#             Exports in goods (value)-US-Dollar_LTU  \
# period
# 2022-02-01                                3.345971
# 2022-03-01                                4.062317
# 2022-04-01                                4.062317
# 2022-05-01                                4.062317
# 2022-06-01                                4.062317
#
#             Exports in goods (value)-US-Dollar_SVN  \
# period
# 2022-02-01                                5.010164
# 2022-03-01                                6.175365
# 2022-04-01                                6.175365
# 2022-05-01                                6.175365
# 2022-06-01                                6.175365
#
#             Exports in goods (value)-US-Dollar_OECD  \
# period
# 2022-02-01                                 1070.440
# 2022-03-01                                 1231.299
# 2022-04-01                                 1231.299
# 2022-05-01                                 1231.299
# 2022-06-01                                 1231.299
#
#             Exports in goods (value)-US-Dollar_OECD_Average
# period
# 2022-02-01                                        28.169484
# 2022-03-01                                        32.402598
# 2022-04-01                                        31.224002
# 2022-05-01                                        31.224002
# 2022-06-01                                        31.224002
#
# [5 rows x 40 columns]

# %%
period_df = pd.DataFrame(data={'period': get_period(start_date, finish_date)})
period_df.set_index('period', inplace=True)
imp_in_goods_df = exp_imp_in_goods_df[(exp_imp_in_goods_df.Subject == 'Imports in goods (value)')]
imp_in_goods_df = imp_in_goods_df[['LOCATION', 'Value']]
locs = imp_in_goods_df['LOCATION'].unique()

imp_in_goods_locs = []
for loc in locs:
    loc_df = imp_in_goods_df[(imp_in_goods_df['LOCATION'] == loc)][['Value']]
    loc_df.rename(columns={'Value': f"Imports in goods (value)-US-Dollar_{loc}"}, inplace=True)
    loc_df = period_df.join(loc_df, how='left')
    imp_in_goods_locs.append(loc_df)
imp_in_goods_df = pd.concat(imp_in_goods_locs, axis=1, join='inner')

fill_nan_last_val(imp_in_goods_df, sym='..')
fill_nan_last_val(imp_in_goods_df)

imp_in_goods_df['Imports in goods (value)-US-Dollar_OECD_Average'] = \
imp_in_goods_df[imp_in_goods_df.columns[:-1]].mean(axis=1)

# %%
imp_in_goods_df.tail()
# Out:
#             Imports in goods (value)-US-Dollar_AUS  \
# period
# 2022-02-01                                22.65962
# 2022-03-01                                25.92466
# 2022-04-01                                22.70632
# 2022-05-01                                22.70632
# 2022-06-01                                22.70632
#
#             Imports in goods (value)-US-Dollar_CAN  \
# period
# 2022-02-01                                39.89195
# 2022-03-01                                50.98204
# 2022-04-01                                50.98204
# 2022-05-01                                50.98204
# 2022-06-01                                50.98204
#
#             Imports in goods (value)-US-Dollar_FRA  \
# period
# 2022-02-01                                64.59635
# 2022-03-01                                73.65316
# 2022-04-01                                73.65316
# 2022-05-01                                73.65316
# 2022-06-01                                73.65316
#
#             Imports in goods (value)-US-Dollar_DEU  \
# period
# 2022-02-01                                127.3428
# 2022-03-01                                142.2904
# 2022-04-01                                142.2904
# 2022-05-01                                142.2904
# 2022-06-01                                142.2904
#
#             Imports in goods (value)-US-Dollar_ITA  \
# period
# 2022-02-01                                55.60778
# 2022-03-01                                62.20090
# 2022-04-01                                62.20090
# 2022-05-01                                62.20090
# 2022-06-01                                62.20090
#
#             Imports in goods (value)-US-Dollar_JPN  \
# period
# 2022-02-01                                68.31826
# 2022-03-01                                74.94086
# 2022-04-01                                70.59300
# 2022-05-01                                70.59300
# 2022-06-01                                70.59300
#
#             Imports in goods (value)-US-Dollar_KOR  \
# period
# 2022-02-01                                53.09772
# 2022-03-01                                63.58105
# 2022-04-01                                60.34150
# 2022-05-01                                60.34150
# 2022-06-01                                60.34150
#
#             Imports in goods (value)-US-Dollar_MEX  \
# period
# 2022-02-01                                44.95308
# 2022-03-01                                51.80168
# 2022-04-01                                49.36353
# 2022-05-01                                49.36353
# 2022-06-01                                49.36353
#
#             Imports in goods (value)-US-Dollar_TUR  \
# period
# 2022-02-01                                27.88449
# 2022-03-01                                30.87621
# 2022-04-01                                29.48048
# 2022-05-01                                29.48048
# 2022-06-01                                29.48048
#
#             Imports in goods (value)-US-Dollar_GBR  ...  \
# period                                              ...
# 2022-02-01                                62.82201  ...
# 2022-03-01                                76.06483  ...
# 2022-04-01                                65.10110  ...
# 2022-05-01                                65.10110  ...
# 2022-06-01                                65.10110  ...
#
#             Imports in goods (value)-US-Dollar_POL  \
# period
# 2022-02-01                                30.87780
# 2022-03-01                                34.38326
# 2022-04-01                                34.38326
# 2022-05-01                                34.38326
# 2022-06-01                                34.38326
#
#             Imports in goods (value)-US-Dollar_PRT  \
# period
# 2022-02-01                                9.300313
# 2022-03-01                                9.940431
# 2022-04-01                                9.940431
# 2022-05-01                                9.940431
# 2022-06-01                                9.940431
#
#             Imports in goods (value)-US-Dollar_SVK  \
# period
# 2022-02-01                                9.324702
# 2022-03-01                                9.817210
# 2022-04-01                                9.817210
# 2022-05-01                                9.817210
# 2022-06-01                                9.817210
#
#             Imports in goods (value)-US-Dollar_SWE  \
# period
# 2022-02-01                                16.15535
# 2022-03-01                                18.61774
# 2022-04-01                                16.51420
# 2022-05-01                                16.51420
# 2022-06-01                                16.51420
#
#             Imports in goods (value)-US-Dollar_EST  \
# period
# 2022-02-01                                2.030271
# 2022-03-01                                2.392003
# 2022-04-01                                2.392003
# 2022-05-01                                2.392003
# 2022-06-01                                2.392003
#
#             Imports in goods (value)-US-Dollar_LVA  \
# period
# 2022-02-01                                2.045586
# 2022-03-01                                2.556114
# 2022-04-01                                2.556114
# 2022-05-01                                2.556114
# 2022-06-01                                2.556114
#
#             Imports in goods (value)-US-Dollar_LTU  \
# period
# 2022-02-01                                3.961167
# 2022-03-01                                4.897969
# 2022-04-01                                4.897969
# 2022-05-01                                4.897969
# 2022-06-01                                4.897969
#
#             Imports in goods (value)-US-Dollar_SVN  \
# period
# 2022-02-01                                5.486394
# 2022-03-01                                6.386648
# 2022-04-01                                6.386648
# 2022-05-01                                6.386648
# 2022-06-01                                6.386648
#
#             Imports in goods (value)-US-Dollar_OECD  \
# period
# 2022-02-01                                 1179.396
# 2022-03-01                                 1383.783
# 2022-04-01                                 1383.783
# 2022-05-01                                 1383.783
# 2022-06-01                                 1383.783
#
#             Imports in goods (value)-US-Dollar_OECD_Average
# period
# 2022-02-01                                        31.036736
# 2022-03-01                                        36.415350
# 2022-04-01                                        35.260327
# 2022-05-01                                        35.260327
# 2022-06-01                                        35.260327
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Fleet & Supply

# %%
filename = 'Total Bulkcarrier Demolition'
dem_df = \
get_df_from_excel(filename, start_date, finish_date,
                  skiprows=5, skipfooter=8, 
                  cols_rename={"DWT million": 'Total Bulkcarrier Demolition_30234',
                               'No': 'Total Bulkcarrier Demolition_30233',
                               "Date": "period"})
fill_nan_last_val(dem_df)

# %% [markdown]
# ## Commodity prices

# %%
filename = 'Commodity Prices_m'
commodity_prices_df = \
get_df_from_excel(filename, start_date, finish_date,
                  skiprows=5, skipfooter=11, cols_rename={"Date": "period"})
fill_nan_last_val(commodity_prices_df)

# %%
commodity_prices_df.tail()
# Out:
#             Brent Crude Oil Price  Japan Steel Ship Plate Commodity Price  \
# period
# 2022-02-01               94.10150                                  1000.0
# 2022-03-01              112.46304                                  1000.0
# 2022-04-01              105.91700                                  1000.0
# 2022-05-01              111.95955                                  1000.0
# 2022-06-01              111.95955                                  1000.0
#
#             Saudi Posted Contract Price - Propane  \
# period
# 2022-02-01                                  775.0
# 2022-03-01                                  895.0
# 2022-04-01                                  940.0
# 2022-05-01                                  850.0
# 2022-06-01                                  850.0
#
#             Saudi Posted Contract Price - Butane  \
# period
# 2022-02-01                                 775.0
# 2022-03-01                                 920.0
# 2022-04-01                                 960.0
# 2022-05-01                                 860.0
# 2022-06-01                                 860.0
#
#             Mont Belvieu Texas Spot Price - Propane  \
# period
# 2022-02-01                                  127.975
# 2022-03-01                                  145.150
# 2022-04-01                                  132.060
# 2022-05-01                                  122.300
# 2022-06-01                                  122.300
#
#             Gasoline Spot Price, FOB US Gulf  \
# period
# 2022-02-01                           2.64475
# 2022-03-01                           3.17450
# 2022-04-01                           3.17360
# 2022-05-01                           3.74000
# 2022-06-01                           3.74000
#
#             Natural Gas Spot Price, Henry Hub USA  \
# period
# 2022-02-01                                 4.7425
# 2022-03-01                                 4.7725
# 2022-04-01                                 6.4060
# 2022-05-01                                 8.1275
# 2022-06-01                                 8.1275
#
#             Natural Gas Spot Price, NGB Point Europe  \
# period
# 2022-02-01                                  29.47959
# 2022-03-01                                  39.48221
# 2022-04-01                                  29.05594
# 2022-05-01                                  21.14925
# 2022-06-01                                  21.14925
#
#             Coking Coal Price, FOB Australia  \
# period
# 2022-02-01                          398.8125
# 2022-03-01                          574.1875
# 2022-04-01                          415.5000
# 2022-05-01                          469.0000
# 2022-06-01                          469.0000
#
#             Natural Gas Spot Price, TTF NW Europe
# period
# 2022-02-01                               29.63262
# 2022-03-01                               41.06364
# 2022-04-01                               31.60211
# 2022-05-01                               27.40366
# 2022-06-01                               27.40366

# %% [markdown]
# ## Inflation and LIBOR

# %%
filename = 'LIBOR Interest Rates_m_14948'
libor_df = \
get_df_from_excel(filename, start_date, finish_date,
                  skiprows=5, skipfooter=6, cols_rename={'%': 'LIBOR Interest Rates_m_14948', "Date": "period"})
fill_nan_last_val(libor_df)

# %%
filename = 'Inflation Indicator'
inflation_df = \
get_df_from_excel(filename, start_date, finish_date,
                  skiprows=5, skipfooter=6, cols_rename={"Date": "period"})
fill_nan_last_val(inflation_df)

# %%
inflation_df.tail()
# Out:
#             Inflation Indicator OECD Europe (excl Turkey)  \
# period
# 2022-02-01                                            9.8
# 2022-03-01                                           11.6
# 2022-04-01                                           12.6
# 2022-05-01                                           12.6
# 2022-06-01                                           12.6
#
#             Inflation Indicator USA  Inflation Indicator Japan  \
# period
# 2022-02-01                      7.9                        0.9
# 2022-03-01                      8.5                        1.2
# 2022-04-01                      8.3                        2.5
# 2022-05-01                      8.3                        2.5
# 2022-06-01                      8.3                        2.5
#
#             Inflation Indicator OECD
# period
# 2022-02-01                       7.8
# 2022-03-01                       8.8
# 2022-04-01                       9.2
# 2022-05-01                       9.2
# 2022-06-01                       9.2

# %% [markdown]
# ## Export & Import

# %%
filename = 'Indonesia Steam Coal Exports (including lignite)'
ind_steam_coal_ex_df = \
get_df_from_excel(filename, start_date, finish_date,
                  skiprows=5, skipfooter=7, 
                  cols_rename={",000 tonnes": filename, "Date": "period"})
fill_nan_last_val(ind_steam_coal_ex_df)

# %%
filename = 'Handysize 28k dwt 20 Year Old Secondhand Prices_47316'
cols_rename = {"Date": "period", '$m':filename}
vessel_yo_20_price_df = \
get_df_from_excel(filename, start_date, finish_date,
                  skiprows=5, skipfooter=7, 
                  cols_rename=cols_rename, parse_dates=['Date'])
fill_nan_last_val(vessel_yo_20_price_df)

# %%
filename = 'China Seaborne Coking Coal Imports'
cols_rename = {"Date": "period", ',000 tonnes': filename}
china_coal_imp_df = \
get_df_from_excel(filename, start_date, finish_date,
                  skiprows=5, skipfooter=7, 
                  cols_rename=cols_rename, parse_dates=['Date'])
fill_nan_last_val(china_coal_imp_df)

# %%
filename = 'China Coking Coal Exports'
cols_rename = {"Date": "period", ',000 tonnes': filename}
china_coal_exp_df = \
get_df_from_excel(filename, start_date, finish_date,
                  skiprows=5, skipfooter=7, 
                  cols_rename=cols_rename, parse_dates=['Date'])
fill_nan_last_val(china_coal_exp_df)

# %%
filename = 'Australia Steam Coal Exports (As Reported)'
cols_rename = {"Date": "period", ',000 tonnes': filename}
australia_coal_exp_df = \
get_df_from_excel(filename, start_date, finish_date,
                  skiprows=5, skipfooter=7, 
                  cols_rename=cols_rename, parse_dates=['Date'])
fill_nan_last_val(australia_coal_exp_df)

# %%
filename = '25-30K DWT Handysize Bulkcarrier Newbuilding Prices'
cols_rename = {"Date": "period", '$m': filename}
vessel_new_price_df = \
get_df_from_excel(filename, start_date, finish_date,
                  skiprows=5, skipfooter=8, 
                  cols_rename=cols_rename, parse_dates=['Date'])
fill_nan_last_val(vessel_new_price_df)

# %%
filename = 'Target_SIN_Timeseries_20220530192831'
cols_rename = {"Date": "period", '$/day': 'target'}
one_year_timecharter_rate_df = \
get_df_from_excel(filename, start_date, finish_date,
                  skiprows=5, skipfooter=7, 
                  cols_rename=cols_rename, parse_dates=['Date'])
#fill_nan_last_val(one_year_timecharter_rate_df)

# %%
filename = '1 Year Timecharter Rate Handysize Bulkcarrier (Long Run Historical Series)_w_534426'
cols_rename = {"Date": "period", '$/day': 'target'}
one_year_timecharter_rate_w_df = \
get_df_from_excel(filename, start_date, finish_date,
                  skiprows=5, skipfooter=7, period='w',
                  cols_rename=cols_rename, parse_dates=['Date'])

# %%
last_year = one_year_timecharter_rate_w_df.index[-1].year
last_month = one_year_timecharter_rate_w_df.index[-1].month
f = ((one_year_timecharter_rate_w_df.index.year == last_year) &
     (one_year_timecharter_rate_w_df.index.month == last_month))
last_value = one_year_timecharter_rate_w_df[f].mean(axis=0).target

# %%
f = ((one_year_timecharter_rate_df.index.year == last_year) &
     (one_year_timecharter_rate_df.index.month == last_month) &
     (one_year_timecharter_rate_df.target.isna()))
if one_year_timecharter_rate_df[f].shape[0]:
    one_year_timecharter_rate_df.loc[f, 'target'] = last_value

# %%
filename = 'Handysize Bulker Sales'
cols_rename = {"Date": "period", '$m': 'Handysize Bulker Sales_33262'}
handysize_bulker_sales_df = \
get_df_from_excel(filename, start_date, finish_date,
                  skiprows=5, skipfooter=10, 
                  cols_rename=cols_rename, parse_dates=['Date'],
                  select_cols=['Date', '$m'])
fill_nan_last_val(handysize_bulker_sales_df)

# %%
filename = 'Handymax Bulker Scrap Value'
cols_rename = {"Date": "period", '$m': 'Handymax Bulker Scrap Value_532217'}
handymax_bulker_scrap_df = \
get_df_from_excel(filename, start_date, finish_date,
                  skiprows=5, skipfooter=10, 
                  cols_rename=cols_rename, parse_dates=['Date'],
                  select_cols=['Date', '$m'])
fill_nan_last_val(handymax_bulker_scrap_df)

# %%
filename = 'Handysize Bulker Scrap Value'
cols_rename = {"Date": "period", '$m': 'Handysize Bulker Scrap Value_8693'}
handysize_bulker_scrap_df = \
get_df_from_excel(filename, start_date, finish_date,
                  skiprows=5, skipfooter=7, 
                  cols_rename=cols_rename, parse_dates=['Date'],
                  select_cols=['Date', '$m'])
fill_nan_last_val(handysize_bulker_scrap_df)

# %% [markdown]
# ## Weekly data

# %%
start_date = date(2000, 1, 7)
finish_date = date(2022, 6, 24)

# %%
filename = 'Commodity Prices_w'
commodity_prices_w_df = \
get_df_from_excel(filename, start_date, finish_date, period='w', 
                  skiprows=5, skipfooter=7, cols_rename={"Date": "period"})
fill_nan_last_val(commodity_prices_w_df)

# %%
commodity_prices_w_df.tail()
# Out:
#             Brent Crude Oil Price  Natural Gas Spot Price, TTF NW Europe
# period
# 2022-05-27               115.5680                               25.31536
# 2022-06-03               119.6260                               25.42693
# 2022-06-10               121.7480                               24.65798
# 2022-06-17               118.9760                               31.45380
# 2022-06-24               112.6425                               31.45380

# %%
filename = 'Secondhand Prices_w'
secondhand_prices_w_df = \
get_df_from_excel(filename, start_date, finish_date, period='w', 
                  skiprows=5, skipfooter=11, cols_rename={"Date": "period"})
#fill_nan_last_val(secondhand_prices_w_df)

# %%
secondhand_prices_w_df.tail()
# Out:
#             Handysize 28K DWT 15 Year Old Secondhand Prices  \
# period
# 2022-05-27                                            12.75
# 2022-06-03                                            12.75
# 2022-06-10                                            13.75
# 2022-06-17                                            13.75
# 2022-06-24                                            13.75
#
#             Handysize 28k dwt 20 Year Old Secondhand Prices  \
# period
# 2022-05-27                                            10.25
# 2022-06-03                                            10.25
# 2022-06-10                                            10.75
# 2022-06-17                                            10.75
# 2022-06-24                                            10.75
#
#             Handysize 37k dwt 5 Year Old Secondhand Prices  \
# period
# 2022-05-27                                            28.5
# 2022-06-03                                            28.5
# 2022-06-10                                            28.5
# 2022-06-17                                            28.5
# 2022-06-24                                            28.5
#
#             Handysize 32K 10 Year Old Secondhand Prices  \
# period
# 2022-05-27                                         19.5
# 2022-06-03                                         19.5
# 2022-06-10                                         19.5
# 2022-06-17                                         19.5
# 2022-06-24                                         19.5
#
#             Handysize 38k dwt Resale Secondhand Prices
# period
# 2022-05-27                                        32.5
# 2022-06-03                                        32.5
# 2022-06-10                                        32.5
# 2022-06-17                                        32.5
# 2022-06-24                                        32.5

# %%
filename = 'Scrap Prices_w'
scrap_prices_w_df = \
get_df_from_excel(filename, start_date, finish_date, period='w', 
                  skiprows=5, skipfooter=8, cols_rename={"Date": "period"})
#fill_nan_last_val(secondhand_prices_w_df)

# %%
scrap_prices_w_df.tail()
# Out:
#             India Scrap Price (Handymax/Handysize Bulkcarrier)  \
# period
# 2022-05-27                                              590.0
# 2022-06-03                                              590.0
# 2022-06-10                                              590.0
# 2022-06-17                                              590.0
# 2022-06-24                                              585.0
#
#             Bangladesh Scrap Price (Handymax/Handysize Bulkcarrier)
# period
# 2022-05-27                                              635.0
# 2022-06-03                                              615.0
# 2022-06-10                                              615.0
# 2022-06-17                                              615.0
# 2022-06-24                                              600.0

# %%
filename = 'Interest Rates_w'
interest_rates_w_df = \
get_df_from_excel(filename, start_date, finish_date, period='w', 
                  skiprows=5, skipfooter=7, cols_rename={"Date": "period"})
fill_nan_last_val(interest_rates_w_df)

# %%
interest_rates_w_df.tail()
# Out:
#             US Interest Rate: Prime  Japan Interest Rate: Short Term Prime  \
# period
# 2022-05-27                      4.0                                  1.475
# 2022-06-03                      4.0                                  1.475
# 2022-06-10                      4.0                                  1.475
# 2022-06-17                      4.0                                  1.475
# 2022-06-24                      4.0                                  1.475
#
#             UK Interest Rate: Official Bank Rate  \
# period
# 2022-05-27                                   2.0
# 2022-06-03                                   2.0
# 2022-06-10                                   2.0
# 2022-06-17                                   2.0
# 2022-06-24                                   2.0
#
#             Switzerland Interest Rate: Policy Rate  \
# period
# 2022-05-27                                    0.00
# 2022-06-03                                    0.00
# 2022-06-10                                    0.00
# 2022-06-17                                    0.25
# 2022-06-24                                    0.25
#
#             Market Interest Rate: US$ LIBOR 6 Months
# period
# 2022-05-27                                     2.054
# 2022-06-03                                     2.069
# 2022-06-10                                     2.266
# 2022-06-17                                     2.748
# 2022-06-24                                     2.748

# %%
filename = 'Handysize Bulkcarrier Newbuilding Prices_w'
newbuild_prices_w_df = \
get_df_from_excel(filename, start_date, finish_date, period='w', 
                  skiprows=5, skipfooter=8, cols_rename={"Date": "period"})
fill_nan_last_val(newbuild_prices_w_df)

# %%
newbuild_prices_w_df.tail()
# Out:
#             38-40K DWT Handysize Bulkcarrier Newbuilding Prices  \
# period
# 2022-05-27                                               30.0
# 2022-06-03                                               30.0
# 2022-06-10                                               30.0
# 2022-06-17                                               30.0
# 2022-06-24                                               30.5
#
#             25-30K DWT Handysize Bulkcarrier Newbuilding Prices
# period
# 2022-05-27                                           26.93182
# 2022-06-03                                           26.93182
# 2022-06-10                                           26.93182
# 2022-06-17                                           26.93182
# 2022-06-24                                           27.38068

# %%
filename = '1 Year Timecharter Rate Handysize Bulkcarrier (Long Run Historical Series)_w'
cols_rename = {"Date": "period", '$/day': 'target'}
one_year_timecharter_rate_w_df = \
get_df_from_excel(filename, start_date, finish_date,
                  skiprows=5, skipfooter=7, period='w',
                  cols_rename=cols_rename, parse_dates=['Date'])

# %%
one_year_timecharter_rate_w_df.tail()
# Out:
#              target
# period
# 2022-05-27  26500.0
# 2022-06-03  26500.0
# 2022-06-10  26500.0
# 2022-06-17  24500.0
# 2022-06-24  23000.0

# %% [markdown]
# # Create dataset (month)

# %%
def get_lagged_df(df, col, n_lag=12):
    lag_period = 1
    df_new = pd.DataFrame()
    col_features = []
    for period_mult in range(1, n_lag + 1, 1):
        f_name = f"{col}_lag_{period_mult}"
        df_new[f_name] = df[col].shift(period_mult * lag_period)
        col_features.append(f_name)
    return df_new[col_features]

# %%
df_list =  [
            #bci_df,
            #ip_df,
            #us_df,
            dem_df,
            #ind_steam_coal_ex_df,
            vessel_yo_20_price_df,
            #china_coal_imp_df,
            #china_coal_exp_df,
            #australia_coal_exp_df,
            vessel_new_price_df, 
            #cci_df, 
            #cli_df,
            #ppi_tm_df,
            #ppi_dm_df,
            handysize_bulker_sales_df,
            #handymax_bulker_scrap_df,
            handysize_bulker_scrap_df,
            #li_irs_df,
            #li_sp_df,
            #exp_in_goods_df[['Exports in goods (value)-US-Dollar_OECD_Average']],
            #imp_in_goods_df[['Imports in goods (value)-US-Dollar_OECD_Average']],
            libor_df,
            inflation_df,
            commodity_prices_df
            ]

# %%
df_list =  [
            bci_df,
            ip_df,
            us_df,
            dem_df,
            ind_steam_coal_ex_df,
            vessel_yo_20_price_df,
            china_coal_imp_df,
            china_coal_exp_df,
            australia_coal_exp_df,
            vessel_new_price_df, 
            cci_df, 
            cli_df,
            ppi_tm_df,
            ppi_dm_df,
            handysize_bulker_sales_df,
            handymax_bulker_scrap_df,
            handysize_bulker_scrap_df,
            li_irs_df,
            li_sp_df,
            exp_in_goods_df[['Exports in goods (value)-US-Dollar_OECD_Average']],
            imp_in_goods_df[['Imports in goods (value)-US-Dollar_OECD_Average']],
            libor_df,
            inflation_df,
            commodity_prices_df
            ]

# %%
final_df = pd.concat([one_year_timecharter_rate_df] + df_list, axis=1)
final_df.to_csv('final_m_full_df.tsv', index=True, sep='\t')

# %%
final_df = pd.concat([one_year_timecharter_rate_df] + df_list, axis=1)
final_df.to_csv('final_m_df.tsv', index=True, sep='\t')

# %%
final_df.shape
# Out:
# (270, 22)

# %% [markdown]
# # Create dataset (week)

# %%
df_w_list = [
            commodity_prices_w_df,
            secondhand_prices_w_df,
            scrap_prices_w_df,
            interest_rates_w_df,
            newbuild_prices_w_df,
            ]

# %%
final_w_df = pd.concat([one_year_timecharter_rate_w_df] + df_w_list, axis=1)
final_w_df.to_csv('final_w_df.tsv', index=True, sep='\t')

# %%
final_w_df[(final_w_df.index >= '2009-09-04')].isna().any()
# Out:
# target                                                     False
# Brent Crude Oil Price                                      False
# Natural Gas Spot Price, TTF NW Europe                      False
# Handysize 28K DWT 15 Year Old Secondhand Prices            False
# Handysize 28k dwt 20 Year Old Secondhand Prices            False
# Handysize 37k dwt 5 Year Old Secondhand Prices             False
# Handysize 32K 10 Year Old Secondhand Prices                False
# Handysize 38k dwt Resale Secondhand Prices                 False
# India Scrap Price (Handymax/Handysize Bulkcarrier)         False
# Bangladesh Scrap Price (Handymax/Handysize Bulkcarrier)    False
# US Interest Rate: Prime                                    False
# Japan Interest Rate: Short Term Prime                      False
# UK Interest Rate: Official Bank Rate                       False
# Switzerland Interest Rate: Policy Rate                     False
# Market Interest Rate: US$ LIBOR 6 Months                   False
# 38-40K DWT Handysize Bulkcarrier Newbuilding Prices        False
# 25-30K DWT Handysize Bulkcarrier Newbuilding Prices        False
# dtype: bool
